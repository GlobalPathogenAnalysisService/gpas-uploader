# %%
import pandas

pandas.options.display.max_columns=999

import gpas_uploader

# %load_ext autoreload
# %autoreload 2

# %%
upload_csv = gpas_uploader.Batch('examples/illumina-fastq-upload.csv', run_parallel=True)

# %%
upload_csv.df
# Out:
#                                      batch run_number sample_name  \
# gpas_sample_name
# e3e13d5c-eab7-4d6f-b26c-bbe6c4ecff60  run1     run1.1     sample1
# 0320396e-d9e0-42f8-9a71-5a49608617e3  run1     run1.2     sample2
# 45c2f9a1-c2f6-45d6-af35-5bcfbf180f0f  run1     run1.2     sample3
#
#                                                   fastq1              fastq2  \
# gpas_sample_name
# e3e13d5c-eab7-4d6f-b26c-bbe6c4ecff60  sample1_1.fastq.gz  sample1_2.fastq.gz
# 0320396e-d9e0-42f8-9a71-5a49608617e3  sample2_1.fastq.gz  sample2_2.fastq.gz
# 45c2f9a1-c2f6-45d6-af35-5bcfbf180f0f  sample3_1.fastq.gz  sample3_2.fastq.gz
#
#                                        control collection_date          tags  \
# gpas_sample_name
# e3e13d5c-eab7-4d6f-b26c-bbe6c4ecff60  negative      2022-02-01  site0:repeat
# 0320396e-d9e0-42f8-9a71-5a49608617e3       NaN      2022-03-01         site0
# 45c2f9a1-c2f6-45d6-af35-5bcfbf180f0f  positive      2022-03-08         site0
#
#                                      country       region district  \
# gpas_sample_name
# e3e13d5c-eab7-4d6f-b26c-bbe6c4ecff60     USA        Texas     1124
# 0320396e-d9e0-42f8-9a71-5a49608617e3     FRA    Finistère      NaN
# 45c2f9a1-c2f6-45d6-af35-5bcfbf180f0f     GBR  Oxfordshire      NaN
#
#                                      specimen_organism   host  \
# gpas_sample_name
# e3e13d5c-eab7-4d6f-b26c-bbe6c4ecff60        SARS-CoV-2  human
# 0320396e-d9e0-42f8-9a71-5a49608617e3        SARS-CoV-2  human
# 45c2f9a1-c2f6-45d6-af35-5bcfbf180f0f        SARS-CoV-2  human
#
#                                      instrument_platform primer_scheme  \
# gpas_sample_name
# e3e13d5c-eab7-4d6f-b26c-bbe6c4ecff60            Illumina          auto
# 0320396e-d9e0-42f8-9a71-5a49608617e3            Illumina          auto
# 45c2f9a1-c2f6-45d6-af35-5bcfbf180f0f            Illumina          auto
#
#                                      gpas_batch  gpas_run_number
# gpas_sample_name
# e3e13d5c-eab7-4d6f-b26c-bbe6c4ecff60  B-8R39222                0
# 0320396e-d9e0-42f8-9a71-5a49608617e3  B-8R39222                1
# 45c2f9a1-c2f6-45d6-af35-5bcfbf180f0f  B-8R39222                1

# %%
upload_csv.valid
# Out:
# True

# %%
upload_csv.validation_errors
# Out:
# Empty DataFrame
# Columns: [error_message]
# Index: []

# %%
upload_csv.validation_json
# Out:
# {'validation': {'status': 'completed',
#   'samples': [{'sample': 'e3e13d5c-eab7-4d6f-b26c-bbe6c4ecff60',
#     'files': ['sample1_1.fastq.gz', 'sample1_2.fastq.gz']},
#    {'sample': '0320396e-d9e0-42f8-9a71-5a49608617e3',
#     'files': ['sample2_1.fastq.gz', 'sample2_2.fastq.gz']},
#    {'sample': '45c2f9a1-c2f6-45d6-af35-5bcfbf180f0f',
#     'files': ['sample3_1.fastq.gz', 'sample3_2.fastq.gz']}]}}

# %%
upload_csv.decontaminate()

# %%
upload_csv.df
# Out:
#                                      batch run_number sample_name  \
# gpas_sample_name
# e3e13d5c-eab7-4d6f-b26c-bbe6c4ecff60  run1     run1.1     sample1
# 0320396e-d9e0-42f8-9a71-5a49608617e3  run1     run1.2     sample2
# 45c2f9a1-c2f6-45d6-af35-5bcfbf180f0f  run1     run1.2     sample3
#
#                                                   fastq1              fastq2  \
# gpas_sample_name
# e3e13d5c-eab7-4d6f-b26c-bbe6c4ecff60  sample1_1.fastq.gz  sample1_2.fastq.gz
# 0320396e-d9e0-42f8-9a71-5a49608617e3  sample2_1.fastq.gz  sample2_2.fastq.gz
# 45c2f9a1-c2f6-45d6-af35-5bcfbf180f0f  sample3_1.fastq.gz  sample3_2.fastq.gz
#
#                                        control collection_date          tags  \
# gpas_sample_name
# e3e13d5c-eab7-4d6f-b26c-bbe6c4ecff60  negative      2022-02-01  site0:repeat
# 0320396e-d9e0-42f8-9a71-5a49608617e3       NaN      2022-03-01         site0
# 45c2f9a1-c2f6-45d6-af35-5bcfbf180f0f  positive      2022-03-08         site0
#
#                                      country       region district  \
# gpas_sample_name
# e3e13d5c-eab7-4d6f-b26c-bbe6c4ecff60     USA        Texas     1124
# 0320396e-d9e0-42f8-9a71-5a49608617e3     FRA    Finistère      NaN
# 45c2f9a1-c2f6-45d6-af35-5bcfbf180f0f     GBR  Oxfordshire      NaN
#
#                                      specimen_organism   host  \
# gpas_sample_name
# e3e13d5c-eab7-4d6f-b26c-bbe6c4ecff60        SARS-CoV-2  human
# 0320396e-d9e0-42f8-9a71-5a49608617e3        SARS-CoV-2  human
# 45c2f9a1-c2f6-45d6-af35-5bcfbf180f0f        SARS-CoV-2  human
#
#                                      instrument_platform primer_scheme  \
# gpas_sample_name
# e3e13d5c-eab7-4d6f-b26c-bbe6c4ecff60            Illumina          auto
# 0320396e-d9e0-42f8-9a71-5a49608617e3            Illumina          auto
# 45c2f9a1-c2f6-45d6-af35-5bcfbf180f0f            Illumina          auto
#
#                                      gpas_batch  gpas_run_number  \
# gpas_sample_name
# e3e13d5c-eab7-4d6f-b26c-bbe6c4ecff60  B-8R39222                0
# 0320396e-d9e0-42f8-9a71-5a49608617e3  B-8R39222                1
# 45c2f9a1-c2f6-45d6-af35-5bcfbf180f0f  B-8R39222                1
#
#                                                                                  r1_uri  \
# gpas_sample_name
# e3e13d5c-eab7-4d6f-b26c-bbe6c4ecff60  /tmp/e3e13d5c-eab7-4d6f-b26c-bbe6c4ecff60.read...
# 0320396e-d9e0-42f8-9a71-5a49608617e3  /tmp/0320396e-d9e0-42f8-9a71-5a49608617e3.read...
# 45c2f9a1-c2f6-45d6-af35-5bcfbf180f0f  /tmp/45c2f9a1-c2f6-45d6-af35-5bcfbf180f0f.read...
#
#                                                                                  r2_uri  \
# gpas_sample_name
# e3e13d5c-eab7-4d6f-b26c-bbe6c4ecff60  /tmp/e3e13d5c-eab7-4d6f-b26c-bbe6c4ecff60.read...
# 0320396e-d9e0-42f8-9a71-5a49608617e3  /tmp/0320396e-d9e0-42f8-9a71-5a49608617e3.read...
# 45c2f9a1-c2f6-45d6-af35-5bcfbf180f0f  /tmp/45c2f9a1-c2f6-45d6-af35-5bcfbf180f0f.read...
#
#                                                                 r1_md5  \
# gpas_sample_name
# e3e13d5c-eab7-4d6f-b26c-bbe6c4ecff60  70d2e71ef2a5bfdfb5e1e8615a36fedd
# 0320396e-d9e0-42f8-9a71-5a49608617e3  70d2e71ef2a5bfdfb5e1e8615a36fedd
# 45c2f9a1-c2f6-45d6-af35-5bcfbf180f0f  70d2e71ef2a5bfdfb5e1e8615a36fedd
#
#                                                                                  r1_sha  \
# gpas_sample_name
# e3e13d5c-eab7-4d6f-b26c-bbe6c4ecff60  d2953dc9c2acc74d1b5ae74ca11661c490eeb7aa16d7c6...
# 0320396e-d9e0-42f8-9a71-5a49608617e3  d2953dc9c2acc74d1b5ae74ca11661c490eeb7aa16d7c6...
# 45c2f9a1-c2f6-45d6-af35-5bcfbf180f0f  d2953dc9c2acc74d1b5ae74ca11661c490eeb7aa16d7c6...
#
#                                                                 r2_md5  \
# gpas_sample_name
# e3e13d5c-eab7-4d6f-b26c-bbe6c4ecff60  51eec565569360fbe875bfd7b5ee8e68
# 0320396e-d9e0-42f8-9a71-5a49608617e3  51eec565569360fbe875bfd7b5ee8e68
# 45c2f9a1-c2f6-45d6-af35-5bcfbf180f0f  51eec565569360fbe875bfd7b5ee8e68
#
#                                                                                  r2_sha
# gpas_sample_name
# e3e13d5c-eab7-4d6f-b26c-bbe6c4ecff60  a899b361b6790ba1df6e9ac048e5e20817cfb10a63a401...
# 0320396e-d9e0-42f8-9a71-5a49608617e3  a899b361b6790ba1df6e9ac048e5e20817cfb10a63a401...
# 45c2f9a1-c2f6-45d6-af35-5bcfbf180f0f  a899b361b6790ba1df6e9ac048e5e20817cfb10a63a401...

# %%
upload_csv.decontamination_json
# Out:
# {'submission': {'status': 'completed',
#   'batch': {'file_name': 'B-8R39222',
#    'uploaded_on': '2022-03-15T15:53:19.326Z+00:00',
#    'run_numbers': [0, 1],
#    'samples': [{'sample': 'e3e13d5c-eab7-4d6f-b26c-bbe6c4ecff60',
#      'run_number': 0,
#      'tags': ['site0', 'repeat'],
#      'control': 'negative',
#      'collection_date': '2022-02-01',
#      'country': 'USA',
#      'region': 'Texas',
#      'district': '1124',
#      'specimen': 'SARS-CoV-2',
#      'host': 'human',
#      'instrument': {'platform': 'Illumina'},
#      'primer_scheme': 'auto',
#      'pe_reads': {'r1_uri': '/tmp/e3e13d5c-eab7-4d6f-b26c-bbe6c4ecff60.reads_1.fastq.gz',
#       'r1_md5': '70d2e71ef2a5bfdfb5e1e8615a36fedd',
#       'r2_uri': '/tmp/e3e13d5c-eab7-4d6f-b26c-bbe6c4ecff60.reads_2.fastq.gz',
#       'r2_md5': '51eec565569360fbe875bfd7b5ee8e68'}},
#     {'sample': '0320396e-d9e0-42f8-9a71-5a49608617e3',
#      'run_number': 1,
#      'tags': ['site0'],
#      'control': nan,
#      'collection_date': '2022-03-01',
#      'country': 'FRA',
#      'region': 'Finistère',
#      'district': nan,
#      'specimen': 'SARS-CoV-2',
#      'host': 'human',
#      'instrument': {'platform': 'Illumina'},
#      'primer_scheme': 'auto',
#      'pe_reads': {'r1_uri': '/tmp/0320396e-d9e0-42f8-9a71-5a49608617e3.reads_1.fastq.gz',
#       'r1_md5': '70d2e71ef2a5bfdfb5e1e8615a36fedd',
#       'r2_uri': '/tmp/0320396e-d9e0-42f8-9a71-5a49608617e3.reads_2.fastq.gz',
#       'r2_md5': '51eec565569360fbe875bfd7b5ee8e68'}},
#     {'sample': '45c2f9a1-c2f6-45d6-af35-5bcfbf180f0f',
#      'run_number': 1,
#      'tags': ['site0'],
#      'control': 'positive',
#      'collection_date': '2022-03-08',
#      'country': 'GBR',
#      'region': 'Oxfordshire',
#      'district': nan,
#      'specimen': 'SARS-CoV-2',
#      'host': 'human',
#      'instrument': {'platform': 'Illumina'},
#      'primer_scheme': 'auto',
#      'pe_reads': {'r1_uri': '/tmp/45c2f9a1-c2f6-45d6-af35-5bcfbf180f0f.reads_1.fastq.gz',
#       'r1_md5': '70d2e71ef2a5bfdfb5e1e8615a36fedd',
#       'r2_uri': '/tmp/45c2f9a1-c2f6-45d6-af35-5bcfbf180f0f.reads_2.fastq.gz',
#       'r2_md5': '51eec565569360fbe875bfd7b5ee8e68'}}]}}}
