# %%
import pandas

pandas.options.display.max_columns=999

import gpas_uploader

# %load_ext autoreload
# %autoreload 2

# %%
upload_csv = gpas_uploader.Batch('examples/illumina-bam-upload.csv', run_parallel=True)

# %%
upload_csv.df
# Out:
#                                      batch run_number sample_name   control  \
# gpas_sample_name
# d4b44fb1-f495-49be-a653-cd549220c492  run1     run1.1     sample1  negative
# a38e58b7-1ced-4b86-941c-085ce5b0eebf  run1     run1.1     sample2       NaN
# c45dd5a2-39fc-4851-9b6b-5a73a1a5aa49  run1     run1.1     sample3       NaN
#
#                                      collection_date          tags country  \
# gpas_sample_name
# d4b44fb1-f495-49be-a653-cd549220c492      2022-02-01  site0:repeat     USA
# a38e58b7-1ced-4b86-941c-085ce5b0eebf      2022-03-01         site0     FRA
# c45dd5a2-39fc-4851-9b6b-5a73a1a5aa49      2022-03-09         site0     GBR
#
#                                          region district specimen_organism  \
# gpas_sample_name
# d4b44fb1-f495-49be-a653-cd549220c492      Texas     1124        SARS-CoV-2
# a38e58b7-1ced-4b86-941c-085ce5b0eebf  Finistère      NaN        SARS-CoV-2
# c45dd5a2-39fc-4851-9b6b-5a73a1a5aa49      Devon      NaN        SARS-CoV-2
#
#                                        host instrument_platform primer_scheme  \
# gpas_sample_name
# d4b44fb1-f495-49be-a653-cd549220c492  human            Illumina          auto
# a38e58b7-1ced-4b86-941c-085ce5b0eebf  human            Illumina          auto
# c45dd5a2-39fc-4851-9b6b-5a73a1a5aa49  human            Illumina          auto
#
#                                      gpas_batch  gpas_run_number  \
# gpas_sample_name
# d4b44fb1-f495-49be-a653-cd549220c492  B-9X3WMMF                0
# a38e58b7-1ced-4b86-941c-085ce5b0eebf  B-9X3WMMF                0
# c45dd5a2-39fc-4851-9b6b-5a73a1a5aa49  B-9X3WMMF                0
#
#                                                   fastq1              fastq2
# gpas_sample_name
# d4b44fb1-f495-49be-a653-cd549220c492  sample1_1.fastq.gz  sample1_2.fastq.gz
# a38e58b7-1ced-4b86-941c-085ce5b0eebf  sample2_1.fastq.gz  sample2_2.fastq.gz
# c45dd5a2-39fc-4851-9b6b-5a73a1a5aa49  sample3_1.fastq.gz  sample3_2.fastq.gz

# %%
upload_csv.errors
# Out:
# Empty DataFrame
# Columns: [error_message]
# Index: []

# %%
upload_csv.validation_json
# Out:
# {'validation': {'status': 'completed',
#   'samples': [{'sample': 'd4b44fb1-f495-49be-a653-cd549220c492',
#     'files': ['sample1_1.fastq.gz', 'sample1_2.fastq.gz']},
#    {'sample': 'a38e58b7-1ced-4b86-941c-085ce5b0eebf',
#     'files': ['sample2_1.fastq.gz', 'sample2_2.fastq.gz']},
#    {'sample': 'c45dd5a2-39fc-4851-9b6b-5a73a1a5aa49',
#     'files': ['sample3_1.fastq.gz', 'sample3_2.fastq.gz']}]}}

# %%
upload_csv.decontaminate()
# Out:
# {"decontamination": {"sample": "sample1", "status": "started", "file": "sample1_1.fastq.gz"}}
# {"decontamination": {"sample": "sample1", "status": "started", "file": "sample1_2.fastq.gz"}}
# {"decontamination": {"sample": "sample1", "status": "completed", "file": "sample1_1.fastq.gz", "cleaned": "/tmp/sample1.reads_1.fastq.gz"}}
# {"decontamination": {"sample": "sample1", "status": "completed", "file": "sample1_2.fastq.gz", "cleaned": "/tmp/sample1.reads_2.fastq.gz"}}
# {"decontamination": {"sample": "sample2", "status": "started", "file": "sample2_1.fastq.gz"}}
# {"decontamination": {"sample": "sample2", "status": "started", "file": "sample2_2.fastq.gz"}}
# {"decontamination": {"sample": "sample2", "status": "completed", "file": "sample2_1.fastq.gz", "cleaned": "/tmp/sample2.reads_1.fastq.gz"}}
# {"decontamination": {"sample": "sample2", "status": "completed", "file": "sample2_2.fastq.gz", "cleaned": "/tmp/sample2.reads_2.fastq.gz"}}
# {"decontamination": {"sample": "sample3", "status": "started", "file": "sample3_1.fastq.gz"}}
# {"decontamination": {"sample": "sample3", "status": "started", "file": "sample3_2.fastq.gz"}}
# {"decontamination": {"sample": "sample3", "status": "completed", "file": "sample3_1.fastq.gz", "cleaned": "/tmp/sample3.reads_1.fastq.gz"}}
# {"decontamination": {"sample": "sample3", "status": "completed", "file": "sample3_2.fastq.gz", "cleaned": "/tmp/sample3.reads_2.fastq.gz"}}

# %%
upload_csv.df
# Out:
#                                      batch run_number sample_name   control  \
# gpas_sample_name
# d4b44fb1-f495-49be-a653-cd549220c492  run1     run1.1     sample1  negative
# a38e58b7-1ced-4b86-941c-085ce5b0eebf  run1     run1.1     sample2       NaN
# c45dd5a2-39fc-4851-9b6b-5a73a1a5aa49  run1     run1.1     sample3       NaN
#
#                                      collection_date          tags country  \
# gpas_sample_name
# d4b44fb1-f495-49be-a653-cd549220c492      2022-02-01  site0:repeat     USA
# a38e58b7-1ced-4b86-941c-085ce5b0eebf      2022-03-01         site0     FRA
# c45dd5a2-39fc-4851-9b6b-5a73a1a5aa49      2022-03-09         site0     GBR
#
#                                          region district specimen_organism  \
# gpas_sample_name
# d4b44fb1-f495-49be-a653-cd549220c492      Texas     1124        SARS-CoV-2
# a38e58b7-1ced-4b86-941c-085ce5b0eebf  Finistère      NaN        SARS-CoV-2
# c45dd5a2-39fc-4851-9b6b-5a73a1a5aa49      Devon      NaN        SARS-CoV-2
#
#                                        host instrument_platform primer_scheme  \
# gpas_sample_name
# d4b44fb1-f495-49be-a653-cd549220c492  human            Illumina          auto
# a38e58b7-1ced-4b86-941c-085ce5b0eebf  human            Illumina          auto
# c45dd5a2-39fc-4851-9b6b-5a73a1a5aa49  human            Illumina          auto
#
#                                      gpas_batch  gpas_run_number  \
# gpas_sample_name
# d4b44fb1-f495-49be-a653-cd549220c492  B-9X3WMMF                0
# a38e58b7-1ced-4b86-941c-085ce5b0eebf  B-9X3WMMF                0
# c45dd5a2-39fc-4851-9b6b-5a73a1a5aa49  B-9X3WMMF                0
#
#                                                   fastq1              fastq2  \
# gpas_sample_name
# d4b44fb1-f495-49be-a653-cd549220c492  sample1_1.fastq.gz  sample1_2.fastq.gz
# a38e58b7-1ced-4b86-941c-085ce5b0eebf  sample2_1.fastq.gz  sample2_2.fastq.gz
# c45dd5a2-39fc-4851-9b6b-5a73a1a5aa49  sample3_1.fastq.gz  sample3_2.fastq.gz
#
#                                                              r1_uri  \
# gpas_sample_name
# d4b44fb1-f495-49be-a653-cd549220c492  /tmp/sample1.reads_1.fastq.gz
# a38e58b7-1ced-4b86-941c-085ce5b0eebf  /tmp/sample2.reads_1.fastq.gz
# c45dd5a2-39fc-4851-9b6b-5a73a1a5aa49  /tmp/sample3.reads_1.fastq.gz
#
#                                                              r2_uri  \
# gpas_sample_name
# d4b44fb1-f495-49be-a653-cd549220c492  /tmp/sample1.reads_2.fastq.gz
# a38e58b7-1ced-4b86-941c-085ce5b0eebf  /tmp/sample2.reads_2.fastq.gz
# c45dd5a2-39fc-4851-9b6b-5a73a1a5aa49  /tmp/sample3.reads_2.fastq.gz
#
#                                                                 r1_md5  \
# gpas_sample_name
# d4b44fb1-f495-49be-a653-cd549220c492  dfe7965a73125aabda857983bac275e3
# a38e58b7-1ced-4b86-941c-085ce5b0eebf  dfe7965a73125aabda857983bac275e3
# c45dd5a2-39fc-4851-9b6b-5a73a1a5aa49  dfe7965a73125aabda857983bac275e3
#
#                                                                                  r1_sha  \
# gpas_sample_name
# d4b44fb1-f495-49be-a653-cd549220c492  1c77eeba224fb5c0b4d55908a85363f4b31923af7b27ba...
# a38e58b7-1ced-4b86-941c-085ce5b0eebf  1c77eeba224fb5c0b4d55908a85363f4b31923af7b27ba...
# c45dd5a2-39fc-4851-9b6b-5a73a1a5aa49  1c77eeba224fb5c0b4d55908a85363f4b31923af7b27ba...
#
#                                                                 r2_md5  \
# gpas_sample_name
# d4b44fb1-f495-49be-a653-cd549220c492  97526116469c99ddda3aff96f2e2cd40
# a38e58b7-1ced-4b86-941c-085ce5b0eebf  97526116469c99ddda3aff96f2e2cd40
# c45dd5a2-39fc-4851-9b6b-5a73a1a5aa49  97526116469c99ddda3aff96f2e2cd40
#
#                                                                                  r2_sha
# gpas_sample_name
# d4b44fb1-f495-49be-a653-cd549220c492  63dd218c66bfbd3066a6b20f45f9d4fd4244b69d40b5df...
# a38e58b7-1ced-4b86-941c-085ce5b0eebf  63dd218c66bfbd3066a6b20f45f9d4fd4244b69d40b5df...
# c45dd5a2-39fc-4851-9b6b-5a73a1a5aa49  63dd218c66bfbd3066a6b20f45f9d4fd4244b69d40b5df...

# %%
upload_csv.decontamination_json
# Out:
# {'submission': {'batch': {'file_name': 'B-9X3WMMF',
#    'uploaded_on': '2022-03-10T09:40:59.065Z+00:00',
#    'run_numbers': [0],
#    'samples': [{'sample': 'd4b44fb1-f495-49be-a653-cd549220c492',
#      'run_number': 0,
#      'tags': ['site0', 'repeat'],
#      'control': 'negative',
#      'collection_date': '2022-02-01',
#      'country': 'USA',
#      'region': 'Texas',
#      'district': '1124',
#      'specimen': 'SARS-CoV-2',
#      'host': 'human',
#      'instrument': {'platform': 'Illumina'},
#      'primer_scheme': 'auto',
#      'pe_reads': {'r1_uri': '/tmp/sample1.reads_1.fastq.gz',
#       'r1_md5': 'dfe7965a73125aabda857983bac275e3',
#       'r2_uri': '/tmp/sample1.reads_2.fastq.gz',
#       'r2_md5': '97526116469c99ddda3aff96f2e2cd40'}},
#     {'sample': 'a38e58b7-1ced-4b86-941c-085ce5b0eebf',
#      'run_number': 0,
#      'tags': ['site0'],
#      'control': nan,
#      'collection_date': '2022-03-01',
#      'country': 'FRA',
#      'region': 'Finistère',
#      'district': nan,
#      'specimen': 'SARS-CoV-2',
#      'host': 'human',
#      'instrument': {'platform': 'Illumina'},
#      'primer_scheme': 'auto',
#      'pe_reads': {'r1_uri': '/tmp/sample2.reads_1.fastq.gz',
#       'r1_md5': 'dfe7965a73125aabda857983bac275e3',
#       'r2_uri': '/tmp/sample2.reads_2.fastq.gz',
#       'r2_md5': '97526116469c99ddda3aff96f2e2cd40'}},
#     {'sample': 'c45dd5a2-39fc-4851-9b6b-5a73a1a5aa49',
#      'run_number': 0,
#      'tags': ['site0'],
#      'control': nan,
#      'collection_date': '2022-03-09',
#      'country': 'GBR',
#      'region': 'Devon',
#      'district': nan,
#      'specimen': 'SARS-CoV-2',
#      'host': 'human',
#      'instrument': {'platform': 'Illumina'},
#      'primer_scheme': 'auto',
#      'pe_reads': {'r1_uri': '/tmp/sample3.reads_1.fastq.gz',
#       'r1_md5': 'dfe7965a73125aabda857983bac275e3',
#       'r2_uri': '/tmp/sample3.reads_2.fastq.gz',
#       'r2_md5': '97526116469c99ddda3aff96f2e2cd40'}}]}}}
