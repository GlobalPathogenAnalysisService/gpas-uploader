# %%
import pandas

pandas.options.display.max_columns=999

import gpas_uploader

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
upload_csv = gpas_uploader.Batch('examples/nanopore-fastq-upload.csv', run_parallel=True)

# %%
upload_csv.df
# Out:
#                                      batch run_number sample_name  \
# gpas_sample_name
# a3fddb1f-1b40-4ad2-88af-e284e6654a8a  run1     run1.1     sample1
# cce6122c-2b10-47ce-bff8-d4efe78aa7f4  run1     run1.1     sample2
# 5a62210a-7ecd-4417-87eb-c9e5a8015c28  run1     run1.1     sample3
#
#                                                  fastq   control  \
# gpas_sample_name
# a3fddb1f-1b40-4ad2-88af-e284e6654a8a  sample1.fastq.gz  negative
# cce6122c-2b10-47ce-bff8-d4efe78aa7f4  sample2.fastq.gz       NaN
# 5a62210a-7ecd-4417-87eb-c9e5a8015c28  sample3.fastq.gz       NaN
#
#                                      collection_date          tags country  \
# gpas_sample_name
# a3fddb1f-1b40-4ad2-88af-e284e6654a8a      2022-02-01  site0:repeat     USA
# cce6122c-2b10-47ce-bff8-d4efe78aa7f4      2022-03-01         site0     FRA
# 5a62210a-7ecd-4417-87eb-c9e5a8015c28      2022-03-09         site0     GBR
#
#                                          region district specimen_organism  \
# gpas_sample_name
# a3fddb1f-1b40-4ad2-88af-e284e6654a8a      Texas     1124        SARS-CoV-2
# cce6122c-2b10-47ce-bff8-d4efe78aa7f4  Finistère      NaN        SARS-CoV-2
# 5a62210a-7ecd-4417-87eb-c9e5a8015c28      Devon      NaN        SARS-CoV-2
#
#                                        host instrument_platform primer_scheme  \
# gpas_sample_name
# a3fddb1f-1b40-4ad2-88af-e284e6654a8a  human            Nanopore          auto
# cce6122c-2b10-47ce-bff8-d4efe78aa7f4  human            Nanopore          auto
# 5a62210a-7ecd-4417-87eb-c9e5a8015c28  human            Nanopore          auto
#
#                                      gpas_batch  gpas_run_number
# gpas_sample_name
# a3fddb1f-1b40-4ad2-88af-e284e6654a8a  B-FB6FB3X                0
# cce6122c-2b10-47ce-bff8-d4efe78aa7f4  B-FB6FB3X                0
# 5a62210a-7ecd-4417-87eb-c9e5a8015c28  B-FB6FB3X                0

# %%
upload_csv.valid
# Out:
# True

# %%
upload_csv.validation_errors
# Out:
# Empty DataFrame
# Columns: [error_message]
# Index: []

# %%
upload_csv.validation_json
# Out:
# {'validation': {'status': 'completed',
#   'samples': [{'sample': 'a3fddb1f-1b40-4ad2-88af-e284e6654a8a',
#     'files': ['sample1.fastq.gz']},
#    {'sample': 'cce6122c-2b10-47ce-bff8-d4efe78aa7f4',
#     'files': ['sample2.fastq.gz']},
#    {'sample': '5a62210a-7ecd-4417-87eb-c9e5a8015c28',
#     'files': ['sample3.fastq.gz']}]}}

# %%
upload_csv.decontaminate()

# %%
upload_csv.df
# Out:
#                                      batch run_number sample_name  \
# gpas_sample_name
# a3fddb1f-1b40-4ad2-88af-e284e6654a8a  run1     run1.1     sample1
# cce6122c-2b10-47ce-bff8-d4efe78aa7f4  run1     run1.1     sample2
# 5a62210a-7ecd-4417-87eb-c9e5a8015c28  run1     run1.1     sample3
#
#                                                  fastq   control  \
# gpas_sample_name
# a3fddb1f-1b40-4ad2-88af-e284e6654a8a  sample1.fastq.gz  negative
# cce6122c-2b10-47ce-bff8-d4efe78aa7f4  sample2.fastq.gz       NaN
# 5a62210a-7ecd-4417-87eb-c9e5a8015c28  sample3.fastq.gz       NaN
#
#                                      collection_date          tags country  \
# gpas_sample_name
# a3fddb1f-1b40-4ad2-88af-e284e6654a8a      2022-02-01  site0:repeat     USA
# cce6122c-2b10-47ce-bff8-d4efe78aa7f4      2022-03-01         site0     FRA
# 5a62210a-7ecd-4417-87eb-c9e5a8015c28      2022-03-09         site0     GBR
#
#                                          region district specimen_organism  \
# gpas_sample_name
# a3fddb1f-1b40-4ad2-88af-e284e6654a8a      Texas     1124        SARS-CoV-2
# cce6122c-2b10-47ce-bff8-d4efe78aa7f4  Finistère      NaN        SARS-CoV-2
# 5a62210a-7ecd-4417-87eb-c9e5a8015c28      Devon      NaN        SARS-CoV-2
#
#                                        host instrument_platform primer_scheme  \
# gpas_sample_name
# a3fddb1f-1b40-4ad2-88af-e284e6654a8a  human            Nanopore          auto
# cce6122c-2b10-47ce-bff8-d4efe78aa7f4  human            Nanopore          auto
# 5a62210a-7ecd-4417-87eb-c9e5a8015c28  human            Nanopore          auto
#
#                                      gpas_batch  gpas_run_number  \
# gpas_sample_name
# a3fddb1f-1b40-4ad2-88af-e284e6654a8a  B-FB6FB3X                0
# cce6122c-2b10-47ce-bff8-d4efe78aa7f4  B-FB6FB3X                0
# 5a62210a-7ecd-4417-87eb-c9e5a8015c28  B-FB6FB3X                0
#
#                                                             r_uri  \
# gpas_sample_name
# a3fddb1f-1b40-4ad2-88af-e284e6654a8a  /tmp/sample1.reads.fastq.gz
# cce6122c-2b10-47ce-bff8-d4efe78aa7f4  /tmp/sample2.reads.fastq.gz
# 5a62210a-7ecd-4417-87eb-c9e5a8015c28  /tmp/sample3.reads.fastq.gz
#
#                                                                  r_md5  \
# gpas_sample_name
# a3fddb1f-1b40-4ad2-88af-e284e6654a8a  f2b0c9122d508d5400f435ca359e3063
# cce6122c-2b10-47ce-bff8-d4efe78aa7f4  f2b0c9122d508d5400f435ca359e3063
# 5a62210a-7ecd-4417-87eb-c9e5a8015c28  f2b0c9122d508d5400f435ca359e3063
#
#                                                                                   r_sha
# gpas_sample_name
# a3fddb1f-1b40-4ad2-88af-e284e6654a8a  b98ecb2dbd6eeeca680895404e6f72623efca2e3f089ea...
# cce6122c-2b10-47ce-bff8-d4efe78aa7f4  b98ecb2dbd6eeeca680895404e6f72623efca2e3f089ea...
# 5a62210a-7ecd-4417-87eb-c9e5a8015c28  b98ecb2dbd6eeeca680895404e6f72623efca2e3f089ea...

# %%
upload_csv.decontamination_json
# Out:
# {'submission': {'status': 'completed',
#   'batch': {'file_name': 'B-9X3WMMF',
#    'uploaded_on': '2022-03-15T14:30:16.069Z+00:00',
#    'run_numbers': [0],
#    'samples': [{'sample': '5e374c60-52c5-43bf-bb9a-e44f3358dc85',
#      'run_number': 0,
#      'tags': ['site0', 'repeat'],
#      'control': 'negative',
#      'collection_date': '2022-02-01',
#      'country': 'USA',
#      'region': 'Texas',
#      'district': '1124',
#      'specimen': 'SARS-CoV-2',
#      'host': 'human',
#      'instrument': {'platform': 'Illumina'},
#      'primer_scheme': 'auto',
#      'pe_reads': {'r1_uri': '/tmp/sample1.reads_1.fastq.gz',
#       'r1_md5': 'dfe7965a73125aabda857983bac275e3',
#       'r2_uri': '/tmp/sample1.reads_2.fastq.gz',
#       'r2_md5': '97526116469c99ddda3aff96f2e2cd40'}},
#     {'sample': 'bbdcd9e9-5501-4237-8603-8c97ba614df2',
#      'run_number': 0,
#      'tags': ['site0'],
#      'control': nan,
#      'collection_date': '2022-03-01',
#      'country': 'FRA',
#      'region': 'Finistère',
#      'district': nan,
#      'specimen': 'SARS-CoV-2',
#      'host': 'human',
#      'instrument': {'platform': 'Illumina'},
#      'primer_scheme': 'auto',
#      'pe_reads': {'r1_uri': '/tmp/sample2.reads_1.fastq.gz',
#       'r1_md5': 'dfe7965a73125aabda857983bac275e3',
#       'r2_uri': '/tmp/sample2.reads_2.fastq.gz',
#       'r2_md5': '97526116469c99ddda3aff96f2e2cd40'}},
#     {'sample': 'f3f48ce3-0daf-4c50-898d-c28b7638cd4f',
#      'run_number': 0,
#      'tags': ['site0'],
#      'control': nan,
#      'collection_date': '2022-03-09',
#      'country': 'GBR',
#      'region': 'Devon',
#      'district': nan,
#      'specimen': 'SARS-CoV-2',
#      'host': 'human',
#      'instrument': {'platform': 'Illumina'},
#      'primer_scheme': 'auto',
#      'pe_reads': {'r1_uri': '/tmp/sample3.reads_1.fastq.gz',
#       'r1_md5': 'dfe7965a73125aabda857983bac275e3',
#       'r2_uri': '/tmp/sample3.reads_2.fastq.gz',
#       'r2_md5': '97526116469c99ddda3aff96f2e2cd40'}}]}}}
