# %%
import pandas

pandas.options.display.max_columns=999

import gpas_uploader

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
upload_csv = gpas_uploader.Batch('examples/illumina-fastq-upload.csv', run_parallel=True)

# %%
upload_csv.df
# Out:
#                                      batch run_number sample_name  \
# gpas_sample_name
# c11d4c11-f7b4-4495-afdc-d94205a3ae71  run1     run1.1     sample1
# 7bedaaee-a0c5-499b-b484-6ed68fe02787  run1     run1.2     sample2
# 57d9fa7b-f975-44bf-9c83-19d2d96d423a  run1     run1.2     sample3
#
#                                                   fastq1              fastq2  \
# gpas_sample_name
# c11d4c11-f7b4-4495-afdc-d94205a3ae71  sample1_1.fastq.gz  sample1_2.fastq.gz
# 7bedaaee-a0c5-499b-b484-6ed68fe02787  sample2_1.fastq.gz  sample2_2.fastq.gz
# 57d9fa7b-f975-44bf-9c83-19d2d96d423a  sample3_1.fastq.gz  sample3_2.fastq.gz
#
#                                        control collection_date          tags  \
# gpas_sample_name
# c11d4c11-f7b4-4495-afdc-d94205a3ae71  negative      2022-02-01  site0:repeat
# 7bedaaee-a0c5-499b-b484-6ed68fe02787       NaN      2022-03-01         site0
# 57d9fa7b-f975-44bf-9c83-19d2d96d423a  positive      2022-03-08         site0
#
#                                      country       region district  \
# gpas_sample_name
# c11d4c11-f7b4-4495-afdc-d94205a3ae71     USA        Texas     1124
# 7bedaaee-a0c5-499b-b484-6ed68fe02787     FRA    Finistère      NaN
# 57d9fa7b-f975-44bf-9c83-19d2d96d423a     GBR  Oxfordshire      NaN
#
#                                      specimen_organism   host  \
# gpas_sample_name
# c11d4c11-f7b4-4495-afdc-d94205a3ae71        SARS-CoV-2  human
# 7bedaaee-a0c5-499b-b484-6ed68fe02787        SARS-CoV-2  human
# 57d9fa7b-f975-44bf-9c83-19d2d96d423a        SARS-CoV-2  human
#
#                                      instrument_platform primer_scheme  \
# gpas_sample_name
# c11d4c11-f7b4-4495-afdc-d94205a3ae71            Illumina          auto
# 7bedaaee-a0c5-499b-b484-6ed68fe02787            Illumina          auto
# 57d9fa7b-f975-44bf-9c83-19d2d96d423a            Illumina          auto
#
#                                      gpas_batch  gpas_run_number
# gpas_sample_name
# c11d4c11-f7b4-4495-afdc-d94205a3ae71  B-8R39222                0
# 7bedaaee-a0c5-499b-b484-6ed68fe02787  B-8R39222                1
# 57d9fa7b-f975-44bf-9c83-19d2d96d423a  B-8R39222                1

# %%
upload_csv.valid
# Out:
# True

# %%
upload_csv.validation_errors
# Out:
# Empty DataFrame
# Columns: [error_message]
# Index: []

# %%
upload_csv.validation_json
# Out:
# {'validation': {'status': 'completed',
#   'samples': [{'sample': 'c11d4c11-f7b4-4495-afdc-d94205a3ae71',
#     'files': ['sample1_1.fastq.gz', 'sample1_2.fastq.gz']},
#    {'sample': '7bedaaee-a0c5-499b-b484-6ed68fe02787',
#     'files': ['sample2_1.fastq.gz', 'sample2_2.fastq.gz']},
#    {'sample': '57d9fa7b-f975-44bf-9c83-19d2d96d423a',
#     'files': ['sample3_1.fastq.gz', 'sample3_2.fastq.gz']}]}}

# %%
upload_csv.decontaminate()

# %%
upload_csv.df
# Out:
#                                      batch run_number sample_name  \
# gpas_sample_name
# c11d4c11-f7b4-4495-afdc-d94205a3ae71  run1     run1.1     sample1
# 7bedaaee-a0c5-499b-b484-6ed68fe02787  run1     run1.2     sample2
# 57d9fa7b-f975-44bf-9c83-19d2d96d423a  run1     run1.2     sample3
#
#                                                   fastq1              fastq2  \
# gpas_sample_name
# c11d4c11-f7b4-4495-afdc-d94205a3ae71  sample1_1.fastq.gz  sample1_2.fastq.gz
# 7bedaaee-a0c5-499b-b484-6ed68fe02787  sample2_1.fastq.gz  sample2_2.fastq.gz
# 57d9fa7b-f975-44bf-9c83-19d2d96d423a  sample3_1.fastq.gz  sample3_2.fastq.gz
#
#                                        control collection_date          tags  \
# gpas_sample_name
# c11d4c11-f7b4-4495-afdc-d94205a3ae71  negative      2022-02-01  site0:repeat
# 7bedaaee-a0c5-499b-b484-6ed68fe02787       NaN      2022-03-01         site0
# 57d9fa7b-f975-44bf-9c83-19d2d96d423a  positive      2022-03-08         site0
#
#                                      country       region district  \
# gpas_sample_name
# c11d4c11-f7b4-4495-afdc-d94205a3ae71     USA        Texas     1124
# 7bedaaee-a0c5-499b-b484-6ed68fe02787     FRA    Finistère      NaN
# 57d9fa7b-f975-44bf-9c83-19d2d96d423a     GBR  Oxfordshire      NaN
#
#                                      specimen_organism   host  \
# gpas_sample_name
# c11d4c11-f7b4-4495-afdc-d94205a3ae71        SARS-CoV-2  human
# 7bedaaee-a0c5-499b-b484-6ed68fe02787        SARS-CoV-2  human
# 57d9fa7b-f975-44bf-9c83-19d2d96d423a        SARS-CoV-2  human
#
#                                      instrument_platform primer_scheme  \
# gpas_sample_name
# c11d4c11-f7b4-4495-afdc-d94205a3ae71            Illumina          auto
# 7bedaaee-a0c5-499b-b484-6ed68fe02787            Illumina          auto
# 57d9fa7b-f975-44bf-9c83-19d2d96d423a            Illumina          auto
#
#                                      gpas_batch  gpas_run_number  \
# gpas_sample_name
# c11d4c11-f7b4-4495-afdc-d94205a3ae71  B-8R39222                0
# 7bedaaee-a0c5-499b-b484-6ed68fe02787  B-8R39222                1
# 57d9fa7b-f975-44bf-9c83-19d2d96d423a  B-8R39222                1
#
#                                                                                  r1_uri  \
# gpas_sample_name
# c11d4c11-f7b4-4495-afdc-d94205a3ae71  /tmp/c11d4c11-f7b4-4495-afdc-d94205a3ae71.read...
# 7bedaaee-a0c5-499b-b484-6ed68fe02787  /tmp/7bedaaee-a0c5-499b-b484-6ed68fe02787.read...
# 57d9fa7b-f975-44bf-9c83-19d2d96d423a  /tmp/57d9fa7b-f975-44bf-9c83-19d2d96d423a.read...
#
#                                                                                  r2_uri  \
# gpas_sample_name
# c11d4c11-f7b4-4495-afdc-d94205a3ae71  /tmp/c11d4c11-f7b4-4495-afdc-d94205a3ae71.read...
# 7bedaaee-a0c5-499b-b484-6ed68fe02787  /tmp/7bedaaee-a0c5-499b-b484-6ed68fe02787.read...
# 57d9fa7b-f975-44bf-9c83-19d2d96d423a  /tmp/57d9fa7b-f975-44bf-9c83-19d2d96d423a.read...
#
#                                                                 r1_md5  \
# gpas_sample_name
# c11d4c11-f7b4-4495-afdc-d94205a3ae71  70d2e71ef2a5bfdfb5e1e8615a36fedd
# 7bedaaee-a0c5-499b-b484-6ed68fe02787  70d2e71ef2a5bfdfb5e1e8615a36fedd
# 57d9fa7b-f975-44bf-9c83-19d2d96d423a  70d2e71ef2a5bfdfb5e1e8615a36fedd
#
#                                                                                  r1_sha  \
# gpas_sample_name
# c11d4c11-f7b4-4495-afdc-d94205a3ae71  d2953dc9c2acc74d1b5ae74ca11661c490eeb7aa16d7c6...
# 7bedaaee-a0c5-499b-b484-6ed68fe02787  d2953dc9c2acc74d1b5ae74ca11661c490eeb7aa16d7c6...
# 57d9fa7b-f975-44bf-9c83-19d2d96d423a  d2953dc9c2acc74d1b5ae74ca11661c490eeb7aa16d7c6...
#
#                                                                 r2_md5  \
# gpas_sample_name
# c11d4c11-f7b4-4495-afdc-d94205a3ae71  51eec565569360fbe875bfd7b5ee8e68
# 7bedaaee-a0c5-499b-b484-6ed68fe02787  51eec565569360fbe875bfd7b5ee8e68
# 57d9fa7b-f975-44bf-9c83-19d2d96d423a  51eec565569360fbe875bfd7b5ee8e68
#
#                                                                                  r2_sha
# gpas_sample_name
# c11d4c11-f7b4-4495-afdc-d94205a3ae71  a899b361b6790ba1df6e9ac048e5e20817cfb10a63a401...
# 7bedaaee-a0c5-499b-b484-6ed68fe02787  a899b361b6790ba1df6e9ac048e5e20817cfb10a63a401...
# 57d9fa7b-f975-44bf-9c83-19d2d96d423a  a899b361b6790ba1df6e9ac048e5e20817cfb10a63a401...

# %%
upload_csv.decontamination_json
# Out:
# {'submission': {'status': 'completed',
#   'batch': {'file_name': 'B-9X3WMMF',
#    'uploaded_on': '2022-03-15T14:30:16.069Z+00:00',
#    'run_numbers': [0],
#    'samples': [{'sample': '5e374c60-52c5-43bf-bb9a-e44f3358dc85',
#      'run_number': 0,
#      'tags': ['site0', 'repeat'],
#      'control': 'negative',
#      'collection_date': '2022-02-01',
#      'country': 'USA',
#      'region': 'Texas',
#      'district': '1124',
#      'specimen': 'SARS-CoV-2',
#      'host': 'human',
#      'instrument': {'platform': 'Illumina'},
#      'primer_scheme': 'auto',
#      'pe_reads': {'r1_uri': '/tmp/sample1.reads_1.fastq.gz',
#       'r1_md5': 'dfe7965a73125aabda857983bac275e3',
#       'r2_uri': '/tmp/sample1.reads_2.fastq.gz',
#       'r2_md5': '97526116469c99ddda3aff96f2e2cd40'}},
#     {'sample': 'bbdcd9e9-5501-4237-8603-8c97ba614df2',
#      'run_number': 0,
#      'tags': ['site0'],
#      'control': nan,
#      'collection_date': '2022-03-01',
#      'country': 'FRA',
#      'region': 'Finistère',
#      'district': nan,
#      'specimen': 'SARS-CoV-2',
#      'host': 'human',
#      'instrument': {'platform': 'Illumina'},
#      'primer_scheme': 'auto',
#      'pe_reads': {'r1_uri': '/tmp/sample2.reads_1.fastq.gz',
#       'r1_md5': 'dfe7965a73125aabda857983bac275e3',
#       'r2_uri': '/tmp/sample2.reads_2.fastq.gz',
#       'r2_md5': '97526116469c99ddda3aff96f2e2cd40'}},
#     {'sample': 'f3f48ce3-0daf-4c50-898d-c28b7638cd4f',
#      'run_number': 0,
#      'tags': ['site0'],
#      'control': nan,
#      'collection_date': '2022-03-09',
#      'country': 'GBR',
#      'region': 'Devon',
#      'district': nan,
#      'specimen': 'SARS-CoV-2',
#      'host': 'human',
#      'instrument': {'platform': 'Illumina'},
#      'primer_scheme': 'auto',
#      'pe_reads': {'r1_uri': '/tmp/sample3.reads_1.fastq.gz',
#       'r1_md5': 'dfe7965a73125aabda857983bac275e3',
#       'r2_uri': '/tmp/sample3.reads_2.fastq.gz',
#       'r2_md5': '97526116469c99ddda3aff96f2e2cd40'}}]}}}
