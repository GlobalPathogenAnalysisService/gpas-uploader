# %%
import pandas

pandas.options.display.max_columns=999

import gpas_uploader

# %load_ext autoreload
# %autoreload 2

# %%
upload_csv = gpas_uploader.Batch('examples/illumina-bam-upload.csv', run_parallel=True)

# %%
upload_csv.df
# Out:
#                                      batch run_number sample_name   control  \
# gpas_sample_name
# 5e374c60-52c5-43bf-bb9a-e44f3358dc85  run1     run1.1     sample1  negative
# bbdcd9e9-5501-4237-8603-8c97ba614df2  run1     run1.1     sample2       NaN
# f3f48ce3-0daf-4c50-898d-c28b7638cd4f  run1     run1.1     sample3       NaN
#
#                                      collection_date          tags country  \
# gpas_sample_name
# 5e374c60-52c5-43bf-bb9a-e44f3358dc85      2022-02-01  site0:repeat     USA
# bbdcd9e9-5501-4237-8603-8c97ba614df2      2022-03-01         site0     FRA
# f3f48ce3-0daf-4c50-898d-c28b7638cd4f      2022-03-09         site0     GBR
#
#                                          region district specimen_organism  \
# gpas_sample_name
# 5e374c60-52c5-43bf-bb9a-e44f3358dc85      Texas     1124        SARS-CoV-2
# bbdcd9e9-5501-4237-8603-8c97ba614df2  Finistère      NaN        SARS-CoV-2
# f3f48ce3-0daf-4c50-898d-c28b7638cd4f      Devon      NaN        SARS-CoV-2
#
#                                        host instrument_platform primer_scheme  \
# gpas_sample_name
# 5e374c60-52c5-43bf-bb9a-e44f3358dc85  human            Illumina          auto
# bbdcd9e9-5501-4237-8603-8c97ba614df2  human            Illumina          auto
# f3f48ce3-0daf-4c50-898d-c28b7638cd4f  human            Illumina          auto
#
#                                      gpas_batch  gpas_run_number  \
# gpas_sample_name
# 5e374c60-52c5-43bf-bb9a-e44f3358dc85  B-9X3WMMF                0
# bbdcd9e9-5501-4237-8603-8c97ba614df2  B-9X3WMMF                0
# f3f48ce3-0daf-4c50-898d-c28b7638cd4f  B-9X3WMMF                0
#
#                                                   fastq1              fastq2
# gpas_sample_name
# 5e374c60-52c5-43bf-bb9a-e44f3358dc85  sample1_1.fastq.gz  sample1_2.fastq.gz
# bbdcd9e9-5501-4237-8603-8c97ba614df2  sample2_1.fastq.gz  sample2_2.fastq.gz
# f3f48ce3-0daf-4c50-898d-c28b7638cd4f  sample3_1.fastq.gz  sample3_2.fastq.gz

# %%
upload_csv.valid
# Out:
# True

# %%
upload_csv.validation_errors
# Out:
# Empty DataFrame
# Columns: [error_message]
# Index: []

# %%
upload_csv.validation_json
# Out:
# {'validation': {'status': 'completed',
#   'samples': [{'sample': '5e374c60-52c5-43bf-bb9a-e44f3358dc85',
#     'files': ['sample1_1.fastq.gz', 'sample1_2.fastq.gz']},
#    {'sample': 'bbdcd9e9-5501-4237-8603-8c97ba614df2',
#     'files': ['sample2_1.fastq.gz', 'sample2_2.fastq.gz']},
#    {'sample': 'f3f48ce3-0daf-4c50-898d-c28b7638cd4f',
#     'files': ['sample3_1.fastq.gz', 'sample3_2.fastq.gz']}]}}

# %%
upload_csv.decontaminate()

# %%
upload_csv.df
# Out:
#                                      batch run_number sample_name   control  \
# gpas_sample_name
# 5e374c60-52c5-43bf-bb9a-e44f3358dc85  run1     run1.1     sample1  negative
# bbdcd9e9-5501-4237-8603-8c97ba614df2  run1     run1.1     sample2       NaN
# f3f48ce3-0daf-4c50-898d-c28b7638cd4f  run1     run1.1     sample3       NaN
#
#                                      collection_date          tags country  \
# gpas_sample_name
# 5e374c60-52c5-43bf-bb9a-e44f3358dc85      2022-02-01  site0:repeat     USA
# bbdcd9e9-5501-4237-8603-8c97ba614df2      2022-03-01         site0     FRA
# f3f48ce3-0daf-4c50-898d-c28b7638cd4f      2022-03-09         site0     GBR
#
#                                          region district specimen_organism  \
# gpas_sample_name
# 5e374c60-52c5-43bf-bb9a-e44f3358dc85      Texas     1124        SARS-CoV-2
# bbdcd9e9-5501-4237-8603-8c97ba614df2  Finistère      NaN        SARS-CoV-2
# f3f48ce3-0daf-4c50-898d-c28b7638cd4f      Devon      NaN        SARS-CoV-2
#
#                                        host instrument_platform primer_scheme  \
# gpas_sample_name
# 5e374c60-52c5-43bf-bb9a-e44f3358dc85  human            Illumina          auto
# bbdcd9e9-5501-4237-8603-8c97ba614df2  human            Illumina          auto
# f3f48ce3-0daf-4c50-898d-c28b7638cd4f  human            Illumina          auto
#
#                                      gpas_batch  gpas_run_number  \
# gpas_sample_name
# 5e374c60-52c5-43bf-bb9a-e44f3358dc85  B-9X3WMMF                0
# bbdcd9e9-5501-4237-8603-8c97ba614df2  B-9X3WMMF                0
# f3f48ce3-0daf-4c50-898d-c28b7638cd4f  B-9X3WMMF                0
#
#                                                   fastq1              fastq2  \
# gpas_sample_name
# 5e374c60-52c5-43bf-bb9a-e44f3358dc85  sample1_1.fastq.gz  sample1_2.fastq.gz
# bbdcd9e9-5501-4237-8603-8c97ba614df2  sample2_1.fastq.gz  sample2_2.fastq.gz
# f3f48ce3-0daf-4c50-898d-c28b7638cd4f  sample3_1.fastq.gz  sample3_2.fastq.gz
#
#                                                              r1_uri  \
# gpas_sample_name
# 5e374c60-52c5-43bf-bb9a-e44f3358dc85  /tmp/sample1.reads_1.fastq.gz
# bbdcd9e9-5501-4237-8603-8c97ba614df2  /tmp/sample2.reads_1.fastq.gz
# f3f48ce3-0daf-4c50-898d-c28b7638cd4f  /tmp/sample3.reads_1.fastq.gz
#
#                                                              r2_uri  \
# gpas_sample_name
# 5e374c60-52c5-43bf-bb9a-e44f3358dc85  /tmp/sample1.reads_2.fastq.gz
# bbdcd9e9-5501-4237-8603-8c97ba614df2  /tmp/sample2.reads_2.fastq.gz
# f3f48ce3-0daf-4c50-898d-c28b7638cd4f  /tmp/sample3.reads_2.fastq.gz
#
#                                                                 r1_md5  \
# gpas_sample_name
# 5e374c60-52c5-43bf-bb9a-e44f3358dc85  dfe7965a73125aabda857983bac275e3
# bbdcd9e9-5501-4237-8603-8c97ba614df2  dfe7965a73125aabda857983bac275e3
# f3f48ce3-0daf-4c50-898d-c28b7638cd4f  dfe7965a73125aabda857983bac275e3
#
#                                                                                  r1_sha  \
# gpas_sample_name
# 5e374c60-52c5-43bf-bb9a-e44f3358dc85  1c77eeba224fb5c0b4d55908a85363f4b31923af7b27ba...
# bbdcd9e9-5501-4237-8603-8c97ba614df2  1c77eeba224fb5c0b4d55908a85363f4b31923af7b27ba...
# f3f48ce3-0daf-4c50-898d-c28b7638cd4f  1c77eeba224fb5c0b4d55908a85363f4b31923af7b27ba...
#
#                                                                 r2_md5  \
# gpas_sample_name
# 5e374c60-52c5-43bf-bb9a-e44f3358dc85  97526116469c99ddda3aff96f2e2cd40
# bbdcd9e9-5501-4237-8603-8c97ba614df2  97526116469c99ddda3aff96f2e2cd40
# f3f48ce3-0daf-4c50-898d-c28b7638cd4f  97526116469c99ddda3aff96f2e2cd40
#
#                                                                                  r2_sha
# gpas_sample_name
# 5e374c60-52c5-43bf-bb9a-e44f3358dc85  63dd218c66bfbd3066a6b20f45f9d4fd4244b69d40b5df...
# bbdcd9e9-5501-4237-8603-8c97ba614df2  63dd218c66bfbd3066a6b20f45f9d4fd4244b69d40b5df...
# f3f48ce3-0daf-4c50-898d-c28b7638cd4f  63dd218c66bfbd3066a6b20f45f9d4fd4244b69d40b5df...

# %%
upload_csv.decontamination_json
# Out:
# {'submission': {'status': 'completed',
#   'batch': {'file_name': 'B-9X3WMMF',
#    'uploaded_on': '2022-03-15T14:30:16.069Z+00:00',
#    'run_numbers': [0],
#    'samples': [{'sample': '5e374c60-52c5-43bf-bb9a-e44f3358dc85',
#      'run_number': 0,
#      'tags': ['site0', 'repeat'],
#      'control': 'negative',
#      'collection_date': '2022-02-01',
#      'country': 'USA',
#      'region': 'Texas',
#      'district': '1124',
#      'specimen': 'SARS-CoV-2',
#      'host': 'human',
#      'instrument': {'platform': 'Illumina'},
#      'primer_scheme': 'auto',
#      'pe_reads': {'r1_uri': '/tmp/sample1.reads_1.fastq.gz',
#       'r1_md5': 'dfe7965a73125aabda857983bac275e3',
#       'r2_uri': '/tmp/sample1.reads_2.fastq.gz',
#       'r2_md5': '97526116469c99ddda3aff96f2e2cd40'}},
#     {'sample': 'bbdcd9e9-5501-4237-8603-8c97ba614df2',
#      'run_number': 0,
#      'tags': ['site0'],
#      'control': nan,
#      'collection_date': '2022-03-01',
#      'country': 'FRA',
#      'region': 'Finistère',
#      'district': nan,
#      'specimen': 'SARS-CoV-2',
#      'host': 'human',
#      'instrument': {'platform': 'Illumina'},
#      'primer_scheme': 'auto',
#      'pe_reads': {'r1_uri': '/tmp/sample2.reads_1.fastq.gz',
#       'r1_md5': 'dfe7965a73125aabda857983bac275e3',
#       'r2_uri': '/tmp/sample2.reads_2.fastq.gz',
#       'r2_md5': '97526116469c99ddda3aff96f2e2cd40'}},
#     {'sample': 'f3f48ce3-0daf-4c50-898d-c28b7638cd4f',
#      'run_number': 0,
#      'tags': ['site0'],
#      'control': nan,
#      'collection_date': '2022-03-09',
#      'country': 'GBR',
#      'region': 'Devon',
#      'district': nan,
#      'specimen': 'SARS-CoV-2',
#      'host': 'human',
#      'instrument': {'platform': 'Illumina'},
#      'primer_scheme': 'auto',
#      'pe_reads': {'r1_uri': '/tmp/sample3.reads_1.fastq.gz',
#       'r1_md5': 'dfe7965a73125aabda857983bac275e3',
#       'r2_uri': '/tmp/sample3.reads_2.fastq.gz',
#       'r2_md5': '97526116469c99ddda3aff96f2e2cd40'}}]}}}
